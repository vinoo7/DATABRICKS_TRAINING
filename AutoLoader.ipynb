-- %%
select current_catalog(),current_schema()

-- %%
USE CATALOG MY_CATALOG;
USE SCHEMA SCHOOL;

-- %%
SELECT * FROM READ_FILES ('/Volumes/my_catalog/school/student_sub_vol', FORMAT=>'CSV', HEADER =>'TRUE')

-- %%
DROP TABLE IF EXISTS student_csv_autoloader;
CREATE OR REFRESH STREAMING TABLE student_csv_autoloader schedule every 1 week as
SELECT * FROM stream READ_FILES ('/Volumes/my_catalog/school/student_sub_vol', FORMAT=>'CSV', HEADER =>true);

-- %%
SELECT * FROM stream READ_FILES ('/Volumes/my_catalog/school/student_sub_vol', FORMAT=>'CSV', HEADER =>true);

-- %%
REFRESH STREAMING TABLE student_csv_autoloader;

-- %%
select current_catalog(),current_schema()

-- %%
select * from student_csv_autoloader;

-- %%
describe table extended student_csv_autoloader;

-- %%
describe history student_csv_autoloader;
