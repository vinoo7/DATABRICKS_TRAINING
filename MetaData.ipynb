-- %%
USE CATALOG MY_CATALOG;
USE SCHEMA SCHOOL;

-- %%
SELECT * FROM read_files('/metastores/36e6471f-9f0c-4718-8b39-da941b25de33/volumes/149fd7f2-f599-41b9-ae18-09e0db3f9932',
format=>'parquet')

-- %%
list '/Volumes/my_catalog/school/student_sub_vol'

-- %%
SELECT * FROM CSV.`/Volumes/my_catalog/school/student_sub_vol` LIMIT 5

-- %%
SELECT *,_metadata.file_modification_time,_metadata.file_name FROM read_files('/Volumes/my_catalog/school/student_sub_vol',
format=>'csv') LIMIT 5
