-- %%
%sql
CREATE CATALOG IF NOT EXISTS my_catalog;

-- %%
%sql
USE CATALOG my_catalog

-- %%
%sql
CREATE SCHEMA IF NOT EXISTS SCHOOL;

-- %%
%sql
USE SCHEMA IDENTIFIER(schema_name)

-- %%
%sql
USE SCHOOL

-- %%
%sql
SELECT current_catalog(),current_schema()

-- %%
%sql
DESCRIBE SCHEMA EXTENDED SCHOOL

-- %%
show tables

-- %%
SHOW TABLES IN my_catalog.school

-- %%
show volumes  --volume if like a file

-- %%
CREATE VOLUME IF NOT EXISTS my_catalog.school.student_raw_data;

-- %%
show volumes in my_catalog.school

-- %%
%python
spark.sql(f"LIST '/Volumes/my_catalog/school/student_raw_data'").display()

-- %%
LIST '/Volumes/my_catalog/school/student_raw_data';

-- %%
select * from csv.`/Volumes/my_catalog/school/student_raw_data/student-dataset.csv`;

-- %%
select * from read_files('/Volumes/my_catalog/school/student_raw_data/student-dataset.csv',format=>'csv',header=>true,inferSchema=>true  )

-- %%
select * from text.`/Volumes/my_catalog/school/student_raw_data/student-dataset.csv`;

-- %%
drop table if exists student

-- %%
create table student as select * from read_files('/Volumes/my_catalog/school/student_raw_data/student-dataset.csv',format=>'csv',header=>true,inferSchema=>true  )

-- %%
select * from student;

-- %%
USE CATALOG my_catalog;
USE SCHEMA school;

-- %%
select current_catalog(),current_schema()

-- %%
create table student as select * from read_files('/Volumes/my_catalog/school/student_raw_data/student-dataset.csv')

-- %%
select * from student;

-- %%
describe detail student

-- %%
describe extended student

-- %%
-- TIME TRAVEL
DESCRIBE HISTORY STUDENT

-- %%
select * from STUDENT where name='Vinu';

--delete from STUDENT where id in(308,309);

DESCRIBE HISTORY STUDENT;

RESTORE TABLE STUDENT TO VERSION AS OF 2;

-- %%
select * from STUDENT

-- %%
INSERT INTO STUDENT
SELECT 
  COALESCE(MAX(id), 0) + 1 AS id,
  'Vinu',
  'India',
  'kerala',
  131.31,
  220.62,
  'M',
  'NA',
  29,
  3.8,
  3.9,
  3.8,
  1,
  4,
  4,
  4,
  NULL
FROM STUDENT

-- %%
delete from student where name='Vinu';

-- %%
update student 
set age=30 
where name='Vinu';

-- %%
select * from student where name='Vinu';

-- %%
describe history student

-- %%
select * from student version as of 2 order by id
