-- %%
%python
print("hello world");

-- %%
USE CATALOG my_catalog;

-- %%
USE SCHEMA SCHOOL;

-- %%
SELECT *
FROM read_files(
  '/Volumes/my_catalog/school/student_raw_data/csvjson.json',
  format => 'json',
  schema => 'id INT, name STRING, age INT'
)
LIMIT 10;

-- %%
LIST '/Volumes/my_catalog/school/student_raw_data'
