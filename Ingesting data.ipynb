-- %%
USE CATALOG my_catalog;
USE SCHEMA school;
SHOW TABLES;

-- %%
LIST '/Volumes/my_catalog/school/student_raw_data'

-- %%
SELECT * FROM read_files('/Volumes/my_catalog/school/student_raw_data/student-dataset.csv');

-- %%
drop table if exists STUDENT_GRADE;

CREATE TABLE  STUDENT_GRADE AS SELECT ID,NAME,math_grade,english_grade, sciences_grade,language_grade from read_files('/Volumes/my_catalog/school/student_raw_data',format=>'csv',header=>'true',inferSchema=>'true');

-- %%
select * from STUDENT_GRADE;

-- %%
show tables;

-- %%
---copy into
drop table if exists teacher;
CREATE TABLE teacher (
  teacher_id INT,
  teacher_name STRING,
  subject STRING
)
USING DELTA;

-- %%
COPY INTO teacher
FROM '/Volumes/my_catalog/school/student_raw_data/teacher.csv'
FILEFORMAT = CSV
FORMAT_OPTIONS (
  'header' = 'true',
  'inferSchema' = 'true'
);

-- %%
show tables;

-- %%
select * from read_files ('/Volumes/my_catalog/school/student_raw_data/teacher _2.csv',format => 'csv',header=>'true',inferSchema=>'true');

-- %%
COPY INTO teacher
FROM '/Volumes/my_catalog/school/student_raw_data/teacher _2.csv'
FILEFORMAT = CSV
FORMAT_OPTIONS (
  'header' = 'true',
  'inferSchema' = 'true'
);

-- %%
select * from teacher;

-- %%
%python
## remove csv files
dbutils.fs.rm('/Volumes/my_catalog/school/student_raw_data/teacher _2.csv');
