-- %%
USE CATALOG my_catalog;
USE SCHEMA school;
SHOW TABLES;

-- %%
LIST '/Volumes/my_catalog/school/student_raw_data'

-- %%
SELECT * FROM read_files('/Volumes/my_catalog/school/student_raw_data/student-dataset.csv');

drop table if exists STUDENT_GRADE;

CREATE TABLE  STUDENT_GRADE AS SELECT ID,NAME,'english.grade' as english_grade,'math.grade' as math_grade,'science.grade' as science_grade,'language.grade' as language_grade from read_files('/Volumes/my_catalog/school/student_raw_data',format=>'csv',header=>'true',inferSchema=>'true');

-- %%
select * from STUDENT_GRADE;
