-- %%
USE CATALOG my_catalog;
USE SCHEMA school

-- %%
select * from my_catalog.school.student_temp_gold;

-- %%
create or replace view student_no_by_country_vw as select no_of_students,student_country from my_catalog.school.student_temp_gold order by no_of_students desc;

-- %%
drop view student_no_by_country

-- %%
select * from student_no_by_country_vw;

-- %%
create or replace function grade_percentage (grade double)
returns double 
return (grade/4)*100

-- %%
select grade_percentage(3.5) as grade_in_percentage
