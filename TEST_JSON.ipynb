-- %%
USE CATALOG my_catalog;
USE SCHEMA SCHOOL;

-- %%
SELECT *
FROM read_files(
  '/Volumes/my_catalog/school/student_raw_data/student-data.json',
  format => 'json'
);

-- %%
SELECT * from
json.`/Volumes/my_catalog/school/student_raw_data/student-data.json`;
