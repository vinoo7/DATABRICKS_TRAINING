-- %%
USE CATALOG my_catalog;
USE SCHEMA SCHOOL;

-- %%
SELECT CURRENT_CATALOG(),CURRENT_SCHEMA()

-- %%
select * from parquet.`/Volumes/my_catalog/school/student_raw_data/student-dataset.parquet`;

-- %%
select * from read_files('/Volumes/my_catalog/school/student_raw_data/student-dataset.parquet',
format=>'parquet')
limit 10;

-- %%
drop table if exists student_read_parquet_bronze;
create table student_read_parquet_bronze as 
select * from read_files ('/Volumes/my_catalog/school/student_raw_data/student-dataset.parquet',format=>'parquet');

-- %%
select * from student_read_parquet_bronze;

-- %%
describe table student_read_parquet_bronze;
describe table extended student_read_parquet_bronze;

-- %%
drop table if exists student_read_parquet_bronze;

CREATE TABLE student_read_parquet_bronze

-- %%
copy into student_read_parquet_bronze
FROM '/Volumes/my_catalog/school/student_raw_data/student-dataset.parquet'
FILEFORMAT =parquet
copy_options ('mergeSchema'='true');

-- %%
select * from student_read_parquet_bronze;

-- %%
DESCRIBE TABLE EXTENDED student_read_parquet_bronze;

-- %%
create volume student_sub_vol

-- %%
drop table if exists student_read_parquet_bronze;

CREATE TABLE student_read_parquet_bronze (id BIGINT,name string)

-- %%
copy into student_read_parquet_bronze
FROM '/Volumes/my_catalog/school/student_sub_vol'
FILEFORMAT =CSV
copy_options ('mergeSchema'='true');

-- %%
select * from student_read_parquet_bronze;

-- %%
copy into student_read_parquet_bronze
FROM '/Volumes/my_catalog/school/student_sub_vol'
FILEFORMAT =parquet
copy_options ('mergeSchema'='true');

-- %%
COPY INTO student_read_parquet_bronze
FROM (
  SELECT
    CAST(id AS BIGINT) AS id,
    *
  FROM '/Volumes/my_catalog/school/student_sub_vol'
)
FILEFORMAT = parquet
COPY_OPTIONS ('mergeSchema' = 'true');
