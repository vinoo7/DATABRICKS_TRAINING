# %%
name=input("Enter your name:")
print(name)

# %%
print(f"user name {DA.username}");

# %%
# %sql
CREATE TABLE student (
  ID INT PRIMARY KEY, Name STRING, Age INT, Gender STRING, Major STRING, GPA DOUBLE
);

# %%
# %sql
select * from student;

# %%
# %sql
insert into student values (1234,'Vinu',25,'Male','CS',3.5);

# %%
# %sql
select * from student;workspace.default.student

# %%
4 % (1 + 9)**2 - 60 // (7 + 2)

# %%
x=input("enter:")
print(x)

# %%
len(name)

# %%
print("Hello","World")

# %%
print("Hello","World", sep="***")

# %%
import warnings
warnings.filterwarnings("ignore");

# %%
import pandas as pd,numpy as np
import matplotlib.pyplot as plt,seaborn as sns
# %matplotlib inline

# %%
inp()=pd.read_csv("application_data.csv")
inp().head()
